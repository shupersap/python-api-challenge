# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 628

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?id=524901"
unit = "imperial"
query_url = f"{url}&appid={weather_api_key}&units={unit}&q="

# Lists for results
lat = []
lng = []
foundCities = []
temp = []
humidity = []
cloudiness = []
windSpeed = []
date = []
country = []

for city in cities:
    try:
        response = requests.get(query_url + city).json()
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        temp.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        windSpeed.append(response["wind"]["speed"])
        date.append(response["dt"])
        country.append(response["sys"]["country"])
        foundCities.append(city)
        print(f"{city} is logged")
    except:
        print(f"{city} is not logged")
# Out:
# bredasdorp is logged
# tubruq is not logged
# port hardy is logged
# gat is logged
# grand gaube is logged
# lebu is logged
# tchaourou is logged
# port elizabeth is logged
# mount gambier is logged
# punta arenas is logged
# los llanos de aridane is logged
# vanimo is logged
# zhuhai is logged
# rikitea is logged
# isangel is logged
# bulgan is logged
# luderitz is logged
# atuona is logged
# suoyarvi is logged
# hammerfest is logged
# saint-philippe is logged
# barrow is logged
# bluff is logged
# mataura is logged
# miri is logged
# doctor pedro p. pena is not logged
# nikolskoye is logged
# ushuaia is logged
# uyuni is logged
# ponta do sol is logged
# port alfred is logged
# richards bay is logged
# castro is logged
# hasilpur is logged
# cap malheureux is logged
# kavieng is logged
# haubourdin is logged
# palabuhanratu is not logged
# okhotsk is logged
# kedrovyy is logged
# upernavik is logged
# lagoa is logged
# mar del plata is logged
# ancud is logged
# belushya guba is not logged
# avarua is logged
# cidreira is logged
# comodoro rivadavia is logged
# new norfolk is logged
# lerwick is logged
# robertson is logged
# zhuzhou is logged
# bandarbeyla is logged
# verkh-usugli is logged
# boyolangu is logged
# butaritari is logged
# lompoc is logged
# kodiak is logged
# farah is logged
# lavrentiya is logged
# clyde river is logged
# omboue is logged
# khatanga is logged
# yellowknife is logged
# tabiauea is not logged
# vardo is logged
# marovoay is logged
# laguna is logged
# yumen is logged
# rocha is logged
# petropavlovsk-kamchatskiy is logged
# kristiansund is logged
# luganville is logged
# edeia is logged
# teahupoo is logged
# busselton is logged
# qaanaaq is logged
# faya is logged
# panguna is logged
# sao joao da barra is logged
# platteville is logged
# road town is logged
# bengkulu is logged
# pisco is logged
# mitu is logged
# saleaula is not logged
# wanlaweyn is logged
# emerald is logged
# lashio is logged
# omsukchan is logged
# kushima is logged
# geraldton is logged
# kjollefjord is logged
# hobart is logged
# saskylakh is logged
# dunedin is logged
# barabai is logged
# khonuu is not logged
# yulara is logged
# latehar is logged
# mananjary is logged
# port keats is logged
# hermanus is logged
# narsipatnam is logged
# berbera is logged
# mogadishu is logged
# taolanaro is not logged
# bay roberts is logged
# mayo is logged
# antofagasta is logged
# helong is logged
# ulladulla is logged
# pevek is logged
# kapaa is logged
# launceston is logged
# dingle is logged
# birjand is logged
# tiksi is logged
# nelson bay is logged
# chokurdakh is logged
# barentsburg is not logged
# sayyan is logged
# dikson is logged
# hilo is logged
# cervo is logged
# suntar is logged
# kaitangata is logged
# vaitupu is not logged
# anadyr is logged
# yanggu is logged
# inuvik is logged
# maragogi is logged
# lorengau is logged
# mecca is logged
# san quintin is logged
# trairi is logged
# biak is logged
# narsaq is logged
# kalmunai is logged
# namatanai is logged
# vila franca do campo is logged
# vaini is logged
# townsville is logged
# katsuura is logged
# alta is logged
# cape town is logged
# kiruna is logged
# marsa matruh is logged
# hithadhoo is logged
# ribeira grande is logged
# illoqqortoormiut is not logged
# berlevag is logged
# rawson is logged
# hofn is logged
# caravelas is logged
# kruisfontein is logged
# nemuro is logged
# tacna is logged
# forfar is logged
# attawapiskat is not logged
# sergeyevka is logged
# sitka is logged
# cherskiy is logged
# bobonong is not logged
# bambous virieux is logged
# ilulissat is logged
# puerto ayora is logged
# mys shmidta is not logged
# nizwa is logged
# de aar is logged
# hobyo is logged
# batabano is logged
# tuktoyaktuk is logged
# carnarvon is logged
# along is logged
# mantua is logged
# nalut is logged
# nuuk is logged
# kavaratti is logged
# nanakuli is logged
# chuy is logged
# la palma is logged
# half moon bay is logged
# san cristobal is logged
# ndele is logged
# yaan is logged
# kamenka is logged
# matagami is logged
# sao filipe is logged
# longlac is not logged
# zhigansk is logged
# maxixe is logged
# gorodets is logged
# tena is logged
# cayenne is logged
# ville-marie is logged
# gizo is logged
# aklavik is logged
# hvide sande is logged
# norman wells is logged
# yuzhno-yeniseyskiy is not logged
# talara is logged
# mahebourg is logged
# saint-augustin is logged
# tulungagung is logged
# nguiu is not logged
# el wasta is not logged
# plyussa is logged
# bethel is logged
# te anau is logged
# palembang is logged
# kendari is logged
# torbay is logged
# asau is logged
# port blair is logged
# ballina is logged
# antalaha is logged
# severo-kurilsk is logged
# albany is logged
# kasempa is logged
# tharrawaddy is not logged
# san carlos is logged
# georgetown is logged
# victoria is logged
# namibe is logged
# sinnamary is logged
# popondetta is logged
# solnechnyy is logged
# altay is logged
# taltal is logged
# pacific grove is logged
# lixourion is logged
# bathsheba is logged
# raudeberg is logged
# vao is logged
# saint-francois is logged
# zhangjiakou is logged
# cairns is logged
# malwan is not logged
# talnakh is logged
# vila velha is logged
# xining is logged
# santiago del estero is logged
# sault sainte marie is logged
# bayan is logged
# jamestown is logged
# kahului is logged
# tiznit is logged
# port lincoln is logged
# sibolga is logged
# padang is logged
# dryden is logged
# beyneu is logged
# tasiilaq is logged
# panjab is logged
# la rioja is logged
# saquena is logged
# artyk is not logged
# kamiiso is logged
# traverse city is logged
# nanortalik is logged
# hasaki is logged
# dzhebariki-khaya is logged
# hosakote is logged
# hazorasp is logged
# ornskoldsvik is logged
# amderma is not logged
# klaksvik is logged
# krasnoselkup is logged
# blatec is logged
# banda aceh is logged
# uthai thani is logged
# saint george is logged
# tura is logged
# sirnak is logged
# cabo san lucas is logged
# san policarpo is logged
# karratha is logged
# rumuruti is logged
# naftah is not logged
# tucumcari is logged
# yulin is logged
# batagay is logged
# tual is logged
# labuhan is logged
# quatre cocos is logged
# placido de castro is logged
# alindao is logged
# izmit is logged
# tupik is logged
# negara is logged
# natal is logged
# meulaboh is logged
# naryan-mar is logged
# hambantota is logged
# shitanjing is logged
# itanhaem is logged
# saldanha is logged
# poum is logged
# jiangyou is logged
# arraial do cabo is logged
# tsihombe is not logged
# fort saint james is logged
# sumbawa is not logged
# palmer is logged
# kuche is not logged
# provost is logged
# brae is logged
# flinders is logged
# riyadh is logged
# chaman is logged
# harindanga is logged
# muros is logged
# taoudenni is logged
# emba is logged
# east london is logged
# zheshart is logged
# shimanovsk is logged
# chilca is logged
# touros is logged
# verkhnyaya inta is logged
# majene is logged
# fuerte olimpo is logged
# souillac is logged
# durban is logged
# moussoro is logged
# margate is logged
# grand river south east is not logged
# gimli is logged
# brigantine is logged
# high level is logged
# zhob is logged
# zapolyarnyy is logged
# clemencia is logged
# chapais is logged
# andijon is logged
# santa lucia is logged
# cape canaveral is logged
# coxim is logged
# nanning is logged
# monaragala is logged
# felipe carrillo puerto is logged
# san patricio is logged
# iqaluit is logged
# alofi is logged
# nueve de julio is logged
# ixtapa is logged
# ranong is logged
# nome is logged
# parati is logged
# waipawa is logged
# santona is logged
# olafsvik is logged
# verkhovyna is logged
# thompson is logged
# san mateo ixtatan is logged
# asfi is logged
# humberto de campos is logged
# chernyshevskiy is logged
# marcona is not logged
# hamilton is logged
# mehamn is logged
# harper is logged
# zhenlai is logged
# choix is logged
# morondava is logged
# sorland is logged
# manavgat is logged
# galiwinku is not logged
# mason city is logged
# oeiras is logged
# roma is logged
# fort nelson is logged
# lisakovsk is logged
# vestmannaeyjar is logged
# djenne is logged
# airai is logged
# guozhen is logged
# samarai is logged
# burnie is logged
# woodway is logged
# dongling is logged
# kindu is logged
# foz is logged
# umzimvubu is not logged
# ambon is logged
# zabaykalsk is logged
# mweka is logged
# mounana is logged
# liancheng is logged
# manokwari is logged
# tupelo is logged
# hun is logged
# salalah is logged
# sao felix do xingu is logged
# sumbe is logged
# san angelo is logged
# morki is logged
# komsomolskiy is logged
# warqla is not logged
# tessalit is logged
# tucuma is logged
# buchanan is logged
# bud is logged
# mateare is logged
# leningradskiy is logged
# coihaique is logged
# sur is logged
# vostok is logged
# faanui is logged
# lata is logged
# portsmouth is logged
# kikwit is logged
# general roca is logged
# kamenskoye is not logged
# puqi is logged
# nizhneyansk is not logged
# srednekolymsk is logged
# buala is logged
# north bend is logged
# galgani is not logged
# santa marinella is logged
# vitim is logged
# rio gallegos is logged
# ozgon is not logged
# port macquarie is logged
# provideniya is logged
# lubango is logged
# yining is logged
# jacareacanga is logged
# ambunti is logged
# gladstone is logged
# jieshi is logged
# ambodifototra is not logged
# kupang is logged
# kaeo is logged
# mouila is logged
# presidencia roque saenz pena is logged
# beringovskiy is logged
# kondinskoye is logged
# cochrane is logged
# jiddah is not logged
# takoradi is logged
# raymond is logged
# fortuna is logged
# cartagena is logged
# aykhal is logged
# xichang is logged
# catabola is logged
# unai is logged
# butiama is logged
# inverness is logged
# cururupu is logged
# lubawa is logged
# la ronge is logged
# valparaiso is logged
# tuatapere is logged
# lac du bonnet is logged
# chumikan is logged
# liverpool is logged
# mithimna is not logged
# sunrise manor is logged
# nicoya is logged
# yarmouth is logged
# mehran is logged
# ascension is logged
# togur is logged
# libenge is logged
# gulu is logged
# camacha is logged
# gaoual is logged
# madras is logged
# bograd is logged
# doka is logged
# whitianga is logged
# martapura is logged
# bandundu is logged
# vung tau is logged
# tawnat is not logged
# horizonte is logged
# kargasok is logged
# ereymentau is logged
# abapo is logged
# nacogdoches is logged
# acapulco is logged
# saint-die is not logged
# freeport is logged
# campana is logged
# oksfjord is logged
# college is logged
# udachnyy is logged
# bonthe is logged
# slavutych is logged
# maqrin is not logged
# iroquois falls is logged
# praia da vitoria is logged
# cascais is logged
# carutapera is logged
# itaituba is logged
# aldan is logged
# barbar is not logged
# kirundo is logged
# chateaubelair is logged
# brasileia is logged
# shelburne is logged
# nautla is logged
# beloha is logged
# pare is logged
# ha tinh is logged
# puerto montt is logged
# elk point is logged
# zaozerne is logged
# borama is not logged
# meadow lake is logged
# guerrero negro is logged
# malacatan is logged
# shieli is logged
# doume is logged
# zamora is logged
# oistins is logged
# lasa is logged
# ambilobe is logged
# turayf is logged
# umtata is logged
# ruatoria is not logged
# grindavik is logged
# jasper is logged
# cockburn town is logged
# sorvag is not logged
# agde is logged
# nadym is logged
# kaffrine is logged
# hami is logged
# lolua is not logged
# codajas is logged
# pula is logged
# yenagoa is logged
# mitsamiouli is logged
# pekan is logged
# kailua is logged
# galveston is logged
# necochea is logged
# sandy bay is logged
# bilibino is logged
# ostrovnoy is logged
# gualaquiza is logged
# northam is logged
# hudson bay is logged
# graulhet is logged
# flin flon is logged
# ozinki is logged
# marawi is logged
# singaparna is logged
# riohacha is logged
# qandala is logged
# atar is logged
# kuytun is logged
# sarkand is logged
# odweyne is logged
# nhulunbuy is logged
# tuensang is logged
# grand centre is not logged
# maketu is logged
# burica is not logged
# newport is logged
# pangnirtung is logged
# hyeres is logged
# esperance is logged
# vaitape is logged
# bingol is logged
# cody is logged
# lashma is logged
# teguise is logged
# ordynskoye is logged
# port-gentil is logged
# aleksandrov gay is logged
# pemangkat is logged
# shivrajpur is logged
# deputatskiy is logged
# shellbrook is logged
# broome is logged
# santa rosalia is logged
# sajanan is logged
# mrirt is not logged
# byron bay is logged
# kuzedeyevo is logged
# machiques is logged
# jumla is logged
# larsnes is logged
# cuamba is logged
# samalaeulu is not logged
# higuey is not logged
# albury is logged
# yefira is not logged
# paamiut is logged
# iquitos is logged
# edson is logged
# aginskoye is logged
# lakes entrance is logged
# sept-iles is logged
# sioux lookout is logged
# mackenzie is logged
# smithers is logged
# riviere-au-renard is logged
# gisborne is logged
# kurumkan is logged
# porbandar is logged
# pyapon is logged
# hays is logged
# kargopol is logged
# nabire is logged
# hope is logged
# dakar is logged
# miyang is logged
# naliya is logged
# kieta is logged
# erenhot is logged
# babu is logged
# turtas is logged
# aksarka is logged
# naze is logged
# wanning is logged
# aiquile is logged
# veraval is logged
# ilheus is logged
# tommot is logged
# orlik is logged
# bombay is logged

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
Weather_DF = pd.DataFrame({"City": foundCities,
                           "Country": country,
                           "Temperature": temp,
                           "Humidity": humidity,
                           "Cloudiness": cloudiness,
                           "Windspeed":windSpeed,
                           "Latitude": lat,
                           "Longitude": lng,
                           "Date": date
                          })
Weather_DF.head()
Weather_DF.to_csv("weather_df.csv")

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
Humidity_100 = Weather_DF[(Weather_DF['Humidity'] > 100)]
Humidity_100
# Out:
# Empty DataFrame
# Columns: [City, Country, Temperature, Humidity, Cloudiness, Windspeed, Latitude, Longitude, Date]
# Index: []

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.

# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#set data to plot
x = Weather_DF["Latitude"]
y = Weather_DF["Temperature"]
plt.scatter(x,y)
#add gridlines
plt.grid()
#add titles and axis labels
plt.title(f"Latitude vs Temperature")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
#export as png
plt.savefig('../output_data/Latitude vs Temperature.png')
#display plot!
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7692\952072210.py in <module>
#      10 plt.ylabel("Temperature (F)")
#      11 #export as png
# ---> 12 plt.savefig('../output_data/Latitude vs Temperature.png')
#      13 #display plot!
#      14 plt.show()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     721 def savefig(*args, **kwargs):
#     722     fig = gcf()
# --> 723     res = fig.savefig(*args, **kwargs)
#     724     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     725     return res
#
# ~\anaconda3\envs\PythonData\lib\site-packages\matplotlib\figure.py in savefig(self, fname, transparent, **kwargs)
#    2201             self.patch.set_visible(frameon)
#    2202
# -> 2203         self.canvas.print_figure(fname, **kwargs)
#    2204
#    2205         if frameon:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2124                     orientation=orientation,
#    2125                     bbox_inches_restore=_bbox_inches_restore,
# -> 2126                     **kwargs)
#    2127             finally:
#    2128                 if bbox_inches and restore_bbox:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     533         else:
#     534             renderer = self.get_renderer()
# --> 535             with cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     536                 _png.write_png(renderer._renderer, fh, self.figure.dpi,
#     537                                metadata={**default_metadata, **metadata})
#
# ~\anaconda3\envs\PythonData\lib\contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# ~\anaconda3\envs\PythonData\lib\site-packages\matplotlib\cbook\__init__.py in open_file_cm(path_or_file, mode, encoding)
#     416 def open_file_cm(path_or_file, mode="r", encoding=None):
#     417     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 418     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     419     if opened:
#     420         with fh:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\matplotlib\cbook\__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     401             fh = bz2.BZ2File(fname, flag)
#     402         else:
# --> 403             fh = open(fname, flag, encoding=encoding)
#     404         opened = True
#     405     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: '../output_data/Latitude vs Temperature.png'

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
x_values = Weather_DF['Latitude']
y_values = Weather_DF['Humidity']
plt.scatter(x_values, y_values)
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('City Latitude vs Humidity')
plt.grid()
plt.savefig('../output_data/Latitude vs Humidity.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
x_values = Weather_DF['Latitude']
y_values = Weather_DF['Cloudiness']
plt.scatter(x_values, y_values)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('City Latitude vs Cloudiness')
plt.grid()
plt.savefig("../output_data/latitude_vs_cloudiness.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
x_values = Weather_DF['Latitude']
y_values = Weather_DF['Windspeed']
plt.scatter(x_values, y_values)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('City Latitude vs Wind Speed')
plt.grid()
plt.savefig("../output_data/latitude_vs_wind_speed.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
northern_lr_df = Weather_DF.loc[Weather_DF["Latitude"] > 0]
southern_lr_df = Weather_DF.loc[Weather_DF["Latitude"] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = (northern_lr_df['Latitude']).astype(float)
y_values = (northern_lr_df['Temperature']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')h
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = (southern_lr_df['Latitude']).astype(float)
y_values = (southern_lr_df['Temperature']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.title('Southern Hemisphere - Max Temp vs. Latitude Linear Regression')
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = (northern_lr_df['Latitude']).astype(float)
y_values = (northern_lr_df['Humidity']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = (southern_lr_df['Latitude']).astype(float)
y_values = (southern_lr_df['Humidity']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = (northern_lr_df['Latitude']).astype(float)
y_values = (northern_lr_df['Cloudiness']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = (southern_lr_df['Latitude']).astype(float)
y_values = (southern_lr_df['Cloudiness']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = (northern_lr_df['Latitude']).astype(float)
y_values = (northern_lr_df['Windspeed']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind  Speed')
plt.title('Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = (southern_lr_df['Latitude']).astype(float)
y_values = (southern_lr_df['Windspeed']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
plt.show()
